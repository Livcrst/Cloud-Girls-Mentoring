# %%
import numpy as np

dado = np.loadtxt('apples_ts.csv', delimiter=',', usecols= np.arange(1,88,11),skiprows= 1 )

# o np.arange serve para criarmos uma lista capturando apenas os valores numericos, excluindo assim a primeira coluna que é relativa a legenda com nome de cidade.
# o parametro skiprow serve para pular a primeira linha da matriz

# %%
dado
# Out:
# array([[ 79.72,  77.16,  78.36,  98.64, 102.08, 127.9 , 131.89, 116.91],
#        [ 42.67,  46.73,  62.2 ,  83.31,  78.08,  95.23, 118.09,  79.2 ],
#        [ 62.55,  65.5 ,  76.08, 101.9 , 101.81, 117.83, 131.12, 115.35],
#        [ 48.26,  44.66,  53.29,  62.04,  71.94,  82.03, 108.93, 102.01],
#        [ 71.25,  69.5 ,  81.25, 109.87, 118.16, 130.31, 126.06, 121.68]])

# %%
dado.ndim #descobrir o numero de dimensões que nossos dados estao variando
# Out:
# 2

# %%
dado.size #Quantos dados tem na tabela de dados
# Out:
# 40

# %%
dado.shape #Quantos retorna quantas linhas e colunas tem os dados
# Out:
# (5, 8)

# %%
dado_transposto = dado.T #Fazer a transposição dos dados da planilha (transposição de matriz)

dado_transposto
# Out:
# array([[ 79.72,  42.67,  62.55,  48.26,  71.25],
#        [ 77.16,  46.73,  65.5 ,  44.66,  69.5 ],
#        [ 78.36,  62.2 ,  76.08,  53.29,  81.25],
#        [ 98.64,  83.31, 101.9 ,  62.04, 109.87],
#        [102.08,  78.08, 101.81,  71.94, 118.16],
#        [127.9 ,  95.23, 117.83,  82.03, 130.31],
#        [131.89, 118.09, 131.12, 108.93, 126.06],
#        [116.91,  79.2 , 115.35, 102.01, 121.68]])

# %%
datas = dado_transposto[:,0]

datas

preco = dado_transposto[:,1:6]

preco
# Out:
# array([[ 42.67,  62.55,  48.26,  71.25],
#        [ 46.73,  65.5 ,  44.66,  69.5 ],
#        [ 62.2 ,  76.08,  53.29,  81.25],
#        [ 83.31, 101.9 ,  62.04, 109.87],
#        [ 78.08, 101.81,  71.94, 118.16],
#        [ 95.23, 117.83,  82.03, 130.31],
#        [118.09, 131.12, 108.93, 126.06],
#        [ 79.2 , 115.35, 102.01, 121.68]])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(datas, preco[:,0])

# %%
Moscow = preco [:,0]
kaliningrad = preco [:,1]
Petersburg = preco [:,2]
Krasnodar = preco [:,3]
# ekaterinburg = preco [:,4]

# %%
Moscow.shape
# Out:
# (8,)

# %%
Moscow_ano_1 = Moscow[0:12]
Moscow_ano_2 = Moscow[13:25]
Moscow_ano_3 = Moscow[25:37]

Moscow_ano_1
# Out:
# array([ 42.67,  46.73,  62.2 ,  83.31,  78.08,  95.23, 118.09,  79.2 ])

# %%
plt.plot(np.arange(1,9,1), Moscow_ano_1)
